# %%
import torch

# %%
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(10, 64),
    nn.ReLU(),

    nn.Linear(64,32),
    nn.ReLU(),

    nn.Linear(32,1)
)

# %%
epochs = 25

# %%
import torch.optim as optim

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.1)

# %%
x = torch.randn(100, 10)
y = X.sum(dim=1, keepdim=True) * 2 + 3 + torch.randn(100, 1)

# %%
for epoch in range(epochs):
  prediction = model(x)
  loss = criterion(prediction, y)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/25], Loss: 8.4474
# Epoch [2/25], Loss: 8.2585
# Epoch [3/25], Loss: 7.3368
# Epoch [4/25], Loss: 5.5070
# Epoch [5/25], Loss: 5.7386
# Epoch [6/25], Loss: 5.0072
# Epoch [7/25], Loss: 3.6597
# Epoch [8/25], Loss: 3.2931
# Epoch [9/25], Loss: 2.9086
# Epoch [10/25], Loss: 3.3003
# Epoch [11/25], Loss: 2.9262
# Epoch [12/25], Loss: 2.5271
# Epoch [13/25], Loss: 1.8211
# Epoch [14/25], Loss: 1.4606
# Epoch [15/25], Loss: 1.8065
# Epoch [16/25], Loss: 1.5833
# Epoch [17/25], Loss: 0.9753
# Epoch [18/25], Loss: 0.9159
# Epoch [19/25], Loss: 0.9380
# Epoch [20/25], Loss: 0.7756
# Epoch [21/25], Loss: 0.6565
# Epoch [22/25], Loss: 0.5359
# Epoch [23/25], Loss: 0.5102
# Epoch [24/25], Loss: 0.5089
# Epoch [25/25], Loss: 0.3162

# %%
model.eval()  # Evaluation Mode
with torch.no_grad():
    sample_input = torch.randn(1, 10)
    predicted_output = model(sample_input)
    print("\nTest Prediction:", predicted_output.item())
# Out:
# Test Prediction: 6.615018844604492

# %%
pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary

# %%
summary(model, input_size=(1, 10))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 1]                    --
# ├─Linear: 1-1                            [1, 64]                   704
# ├─ReLU: 1-2                              [1, 64]                   --
# ├─Linear: 1-3                            [1, 32]                   2,080
# ├─ReLU: 1-4                              [1, 32]                   --
# ├─Linear: 1-5                            [1, 1]                    33
# ==========================================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ==========================================================================================
